# %% [markdown]
# <h1><center> Python demo </center></h1>
# <h2><center>Current car prices from bazos.cz</center></h2>
# <h3><center>Daniel Brosko, Vojtěch Suchánek</center></h3>
#
# Our goal is to web-scrape advertisements listed on website bazos.cz, which is currently one of the most used websites for selling used cars in Czech republic. It has more than 15 000 car adds daily. On the other hand, it has really poor search options, which pretty much complicates searching for desired car based on your parameters.
#
# We are going to code algorithm, which will scan adds for the current day, pick those, which fulfill our conditions on date and car type and save their links. Then we will go to each link and save the text of the add. Then we will try to analyze the text of the add to find our parameters. In the end, we will perform some visualizations of distribution of price and selected parameters and try to select some underprices offers.
#
# This task might be better to perform continuouslly, for example each hour, to not overload the website. This approach might also allow for longer time period to analyze the data. But since this project should be designed as one-time run, we decided to limit the data to only current date.

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import date
from datetime import datetime
import time

# %%
bots = requests.get('https://auto.bazos.cz/robots.txt')
#print(bots.text)

# %% [markdown]
# From the robots page we can see that our actions done in our projects are allowed, since we are not gonna use these search commands.

# %% [markdown]
# Here we will get the main page from car section of bazos.

# %%
# firstly, we define the input variable so the user can search according to their preference
user_search_input = str("octávia 3")
user_search_input = re.sub(r"[^\w\s]", '', user_search_input)
user_search_input = re.sub(r"\s+", '+', user_search_input)

no_of_adv_url = 'https://auto.bazos.cz/0/?hledat=' + user_search_input + '&hlokalita=&humkreis=25&cenaod=&cenado=&order='

page = requests.get(no_of_adv_url)
no_of_adv_html = BeautifulSoup(page.text, 'html')

get_no_adv = no_of_adv_html.find('div', {'class':'listainzerat inzeratyflex'})
get_no_adv = get_no_adv.find('div', {'class':'inzeratynadpis'})
get_no_adv = get_no_adv.text
get_no_adv = get_no_adv.split("z ")[-1]
number_adv = get_no_adv.replace(" ","")
number_adv = int(number_adv)
# works properly, "number_adv" represents total number of advertisements for particular search input,
# however, we modify it so that it correspondents correctly to the structure of page
no_of_ad_lists = number_adv // 20
if number_adv % 20 == 0:
    number_adv = no_of_ad_lists * 19
else:
    number_adv = no_of_ad_lists * 20


number_sequence = range(0, 60, 20) #start, stop (not included), step // changed for testing
# we create empty list for saving the urls,
# and then append other tabs with offers (since there are only 20 offers per tab by default)
main_url_list = list()

for i in range(0,len(number_sequence)):
    url = f'https://auto.bazos.cz/{number_sequence[i]}/'
    url = url + '?hledat=' + user_search_input + '&hlokalita=&humkreis=25&cenaod=&cenado=&order='
    main_url_list.append(url)
    time.sleep(0.03)
# here we can check the list of urls for particular tabs
print(main_url_list)
# Out:
# ['https://auto.bazos.cz/0/?hledat=octávia+3&hlokalita=&humkreis=25&cenaod=&cenado=&order=', 'https://auto.bazos.cz/20/?hledat=octávia+3&hlokalita=&humkreis=25&cenaod=&cenado=&order=', 'https://auto.bazos.cz/40/?hledat=octávia+3&hlokalita=&humkreis=25&cenaod=&cenado=&order=']

# %%
# in the next step, we get the text of each of those tabs using the BeautifulSoup function,
# and save it as elements of the "soup_list"
soup_list = list()
for url in main_url_list:
    page = requests.get(url)
    soup_list.append(BeautifulSoup(page.text, 'html'))
#    time.sleep(0.03)
print(soup_list)
# Out:
# [<!DOCTYPE html>
# <html lang="cs">
# <head>
# <title>Octávia 3 bazar - Auto | Bazoš.cz</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Auto - Octávia 3 bazar. Vybírejte z 2 149 inzerátů. Prodej snadno a rychle na Bazoši. Přes půl milionů uživatelů za den. Najděte co potřebujete." name="description"/><link href="https://auto.bazos.cz/inzeraty/oct%C3%A1via-3/" rel="canonical"/><meta content="1055875657" property="fb:admins"/>
# <link href="https://www.bazos.cz/bazos60s.css" rel="stylesheet" type="text/css"/><link as="image" href="https://www.bazos.cz/obrazky/bazos.svg" rel="preload"/>
# <link href="https://www.bazos.cz/bazosprint.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://www.bazos.cz/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.bazos.cz/obrazky/icon-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://www.bazos.cz/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://www.bazos.cz/rss.php?rub=au&amp;hledat=oct%c3%a1via+3" rel="alternate" title="Auto - Octávia 3 RSS | Bazos.cz" type="application/rss+xml"/>
# <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
# (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
#   arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
# </script><script>
# var xhr = new XMLHttpRequest();
# var naseptavac_value = '';
# function naseptavac(value) {
#   if (value=='')  {
#   	naseptavac_value = '';
#   	document.getElementById('vysledek').innerHTML='';
#   	}
# else {
# 	if (naseptavac_value == value) {
# 		return false;
# 	}
# 	naseptavac_value = value;
# 	setTimeout(function () {
# 		if (naseptavac_value != value) {
# 			return false;
# 		}
# 		xhr.onreadystatechange = function() {
#  		 if (this.readyState == 4 && naseptavac_value == value){
# 				document.getElementById('vysledek').innerHTML = this.responseText;
# 			}
#  		 };
# 		xhr.open('GET', '/suggest.php?rubnas=AU&catnas=&qnas='+encodeURIComponent(naseptavac_value));
# 		xhr.send();
# 	}, 250);
# }
# }
#
# var naseptavacpsc_value = '';
# function naseptavacpsc(value) {
#   if (value=='')  {
#   	naseptavacpsc_value = '';
#   	document.getElementById('vysledekpsc').innerHTML='<table cellpadding=\"3\" cellspacing=\"0\" class=\"tablenaspsc\"><tr><td class=\"act\" onclick=\"getLocation();\"><b>Inzeráty v okolí</b></td></tr></table>';
#   	}
# else {
# 	if (naseptavacpsc_value == value) {
# 		return false;
# 	}
# 	naseptavacpsc_value = value;
# 	setTimeout(function () {
# 		if (naseptavacpsc_value != value) {
# 			return false;
# 		}
# 		xhr.onreadystatechange = function() {
#  		 if (this.readyState == 4 && naseptavacpsc_value == value){
# 				document.getElementById('vysledekpsc').innerHTML = this.responseText;
# 			}
#  		 };
# 		xhr.open('GET', '/suggestpsc.php?qnaspsc='+encodeURIComponent(naseptavacpsc_value));
# 		xhr.send();
# 	}, 250);
# }
# }
#
# function getLocation() {
# if (navigator.geolocation) {navigator.geolocation.getCurrentPosition(showPosition);}
# else {document.getElementById('hlokalita').value = '';}
# }
# function showPosition(position) {
# 		xhr.onreadystatechange = function() {
#  		 if (this.readyState == 4){
# 				document.getElementById('hlokalita').value = this.responseText;
# 				document.forms['formt'].submit();
# 			}
#  		 };
# 		xhr.open('GET', '/zip.php?latitude='+encodeURIComponent(position.coords.latitude)+'&longitude='+encodeURIComponent(position.coords.longitude));
# 		xhr.send();
# }
#
# var agent_value = '';
# function agentclick() {
#   if (document.getElementById('agentmail').value=='')  {
#   	document.getElementById("agentmail").focus();
#     return false;
#   	}
# else {
# agent_value = document.getElementById('agentmail').value;
# xhr.onreadystatechange = function() {
#   if (this.readyState == 4){
# 				document.getElementById('overlay').innerHTML = this.responseText;
# 			}
#   };
# xhr.open("GET", '/agent.php?hledat=octávia 3&rubrikav=AU&hlokalita=&humkreis=&cenaod=&cenado=&cat=&typ=&agentmail='+encodeURIComponent(agent_value));
# xhr.send();
# }
# }
#
# function odeslatrequest(value) {
# xhr.onreadystatechange = function() {
#   if (this.readyState == 4){
# 				document.getElementById('overlay').innerHTML = this.responseText;
# 			}
#   };
# xhr.open("GET", value);
# xhr.send();
# }
# function overlay() {
# 	el = document.getElementById("overlay");
# 	el.style.display = (el.style.display == "inline") ? "none" : "inline";
# }
# </script>
# <script async="" src="https://www.bazos.cz/eucookiecz.js"></script></head>
# <body>
# <div class="sirka">
# <div class="listalogor">
# <div class="listalogol"><a href="https://www.bazos.cz/" title="Bazos.cz - Inzerce, bazar"><img alt="Bazos.cz - Inzerce, inzeráty" height="34" src="https://www.bazos.cz/obrazky/bazos.svg" width="199"/></a></div>
# <div class="listalogom"><b>... bazar pro každého</b></div>
# <div class="listalogop"><a href="https://www.bazos.cz/oblibene.php"><b>Oblíbené inzeráty</b></a> <a href="https://www.bazos.cz/moje-inzeraty.php"><b>Moje inzeráty</b></a> <a href="/pridat-inzerat.php"><b><span class="pridati">Přidat inzerát</span></b></a></div>
# </div>
# <form action="https://auto.bazos.cz/" id="formt" method="get" name="formt">
# <div class="listah">
# <div class="rubriky">
# <b>
# Co: <span class="vysokoli"><span id="vysledek"></span><input autocomplete="off" id="hledat" maxlength="256" name="hledat" onkeyup="naseptavac(this.value);" size="17" title="Co? Vyhledávaný výraz" type="search" value="octávia 3"/></span>
# <select name="rubriky" onchange="this.form.submit();" title="Vyber rubriku">
# <option value="www">Všechny rubriky</option>
# <option selected="" value="auto">Auto</option><option value="deti">Děti</option><option value="dum">Dům a zahrada</option><option value="elektro">Elektro</option><option value="foto">Foto</option><option value="hudba">Hudba</option><option value="knihy">Knihy</option><option value="mobil">Mobily</option><option value="motorky">Motorky</option><option value="nabytek">Nábytek</option><option value="obleceni">Oblečení</option><option value="pc">PC</option><option value="prace">Práce</option><option value="reality">Reality</option><option value="sluzby">Služby</option><option value="sport">Sport</option><option value="stroje">Stroje</option><option value="vstupenky">Vstupenky</option><option value="zvirata">Zvířata</option><option value="ostatni">Ostatní</option></select>
#
# Lokalita: <span class="vysokolipsc"><span id="vysledekpsc"></span><input autocomplete="off" id="hlokalita" maxlength="25" name="hlokalita" onclick="naseptavacpsc(this.value);" onkeyup="naseptavacpsc(this.value);" size="4" style="-webkit-appearance: none;" title="Kde? PSČ (místo)" type="search" value=""/></span>
# Okolí: <input name="humkreis" size="3" style="width: 25px;" title="Okolí v km" value="25"/> km
# Cena od: <input maxlength="12" name="cenaod" size="5" title="Cena od Kč" value=""/> - do: <input maxlength="12" name="cenado" size="5" title="Cena do Kč" value=""/> Kč <input name="Submit" type="submit" value="Hledat"/>
# <input name="kitx" type="hidden" value="ano"/></b>
# </div>
# </div>
# </form>
# <div class="drobky"><a href="https://www.bazos.cz/" title="Inzerce Bazoš">Hlavní stránka</a>  &gt; <a href="https://auto.bazos.cz">Auto</a> &gt; <h1 class="nadpiskategorie">octávia 3</h1></div>
# <br/>
# <div class="flexmain"><div class="menuleft">
# <div class="nadpismenu">Osobní auta</div>
# <div class="barvalmenu">
# <div class="barvaleva">
# <a href="/alfa/">Alfa Romeo</a>
# <a href="/audi/">Audi</a>
# <a href="/bmw/">BMW</a>
# <a href="/citroen/">Citroën</a>
# <a href="/dacia/">Dacia</a>
# <a href="/fiat/">Fiat</a>
# <a href="/ford/">Ford</a>
# <a href="/honda/">Honda</a>
# <a href="/hyundai/">Hyundai</a>
# <a href="/chevrolet/">Chevrolet</a>
# <a href="/kia/">Kia</a>
# <a href="/mazda/">Mazda</a>
# <a href="/mercedes/">Mercedes-Benz</a>
# <a href="/mitsubishi/">Mitsubishi</a>
# <a href="/nissan/">Nissan</a>
# <a href="/opel/">Opel</a>
# <a href="/peugeot/">Peugeot</a>
# <a href="/renault/">Renault</a>
# <a href="/seat/">Seat</a>
# <a href="/suzuki/">Suzuki</a>
# <a href="/skoda/">Škoda</a>
# <a href="/toyota/">Toyota</a>
# <a href="/volkswagen/">Volkswagen</a>
# <a href="/volvo/">Volvo</a>
# <a href="/ostatni/">Ostatní značky</a>
# <br/>
# <a href="https://elektro.bazos.cz/autoradia/">Autorádia</a>
# <a href="https://pc.bazos.cz/gps/">GPS navigace</a>
# <a href="/havarovana/">Havarovaná auta</a>
# <a href="/nahradnidily/">Náhradní díly</a>
# <a href="/pneumatiky/">Pneumatiky, kola</a>
# <a href="/prislusenstvi/">Příslušenství</a>
# <a href="/tuning/">Tuning</a>
# <a href="/veterani/">Veteráni</a>
# </div></div>
# <br/>
# <div class="nadpismenu">Užitková vozidla</div>
# <div class="barvalmenu">
# <div class="barvaleva">
# <a href="/autobusy/">Autobusy</a>
# <a href="/dodavka/">Dodávky</a>
# <a href="/mikrobus/">Mikrobusy</a>
# <a href="/karavany/">Karavany, vozíky</a>
# <a href="/nakladni/">Nákladní auta</a>
# <a href="/pickup/">Pick-up</a>
# <a href="https://stroje.bazos.cz/">Stroje</a>
# <a href="/ostatniuzitkova/">Ostatní</a>
# <br/>
# <a href="/havarovanauzitkova/">Havarovaná</a>
# <a href="/nahradnidilyuzitkova/">Náhradní díly</a>
# </div>
# </div>
# <br/>
# <div class="nadpismenu">Moto</div>
# <div class="barvalmenu">
# <div class="barvaleva">
# <a href="https://motorky.bazos.cz/">Motorky, Skútry</a>
# </div></div>
# <br/><span class="mobilskryt">
# <iframe src="https://www.bazos.cz/reklamajasminka.php" style="border: 0px;width:100%; height:300px;overflow: hidden;"></iframe></span></div><div class="maincontent">
# <div class="listainzerat inzeratyflex">
# <div class="inzeratynadpis"><img alt="List inzerátů" class="gallerylista" height="16" src="https://www.bazos.cz/obrazky/list.gif" width="18"/> <a href="/inzeraty/oct%C3%A1via-3/?gal=g" rel="nofollow"><img alt="Galerie" class="gallerylist" height="16" src="https://www.bazos.cz/obrazky/gallery.gif" width="18"/></a> Zobrazeno 1-20 inzerátů z 2 149</div>
# <div class="inzeratycena"><b><a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=1" rel="nofollow">Cena</a></b></div>
# <div class="inzeratylok">Lokalita</div>
# <div class="inzeratyview"><a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=3" rel="nofollow">Zobrazeno</a></div>
# </div><button onclick="odeslatrequest('/agent.php?teloverit=');overlay();" type="button">Nové inzeráty e-mailem</button>
# <div id="overlay">
# <div></div>
# </div>
# <div id="container_one"></div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/157075143/skoda-octavia-3-20tdi-110kw-dsg-plna-zaruka-2-roky-zdarma.php"><img alt="Škoda Octavia 3 2.0TDI 110kW DSG - PLNÁ ZÁRUKA 2 ROKY ZDARMA" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/143/157075143.jpg?t=1661873705" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/157075143/skoda-octavia-3-20tdi-110kw-dsg-plna-zaruka-2-roky-zdarma.php">Škoda Octavia 3 2.0TDI 110kW DSG - PLNÁ ZÁRUKA 2 ROKY ZDARMA</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 21x Platí do 11.10. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">S tímhle autem můžete rovnou vyrazit na cesty. Vybrali jsme ho pečlivě přímo u autorizovaného dealera Škoda. Zkontrolovali vlastním servisem. A vybavili širokou dvouletou zárukou. Doveze vás kamkoliv stejně dobře jako nové. Jen za citelně lepší cenu. ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  437 000 Kč</b></div>
# <div class="inzeratylok">Ostrava<br/>722 00</div>
# <div class="inzeratyview">183 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157075143&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157075143&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=2424587&amp;idphone=9428&amp;jmeno=N%C4%9Bkter%C3%A9+dal%C5%A1%C3%AD+vozy+AutoDraft" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157075143.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/157035970/octavia-scout-4x420tdi-110kwr2018dsgledacc123tiskm.php"><img alt="OCTAVIA SCOUT 4x4/2.0Tdi-110kw/r.2018/DSG/LED/ACC/123tisKM" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/970/157035970.jpg?t=1661791535" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/157035970/octavia-scout-4x420tdi-110kwr2018dsgledacc123tiskm.php">OCTAVIA SCOUT 4x4/2.0Tdi-110kw/r.2018/DSG/LED/ACC/123tisKM</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 21x Platí do 10.10. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Dobrý den,
# prodám krásnou a velmi dobře vybavenou ŠKODA OCTAVIA <b>3</b> SCOUT 4X4 rok 2018 (facelift) motorem 2.0tdi-110kw/150ps doplněným DSG převodovkou navíc v elegantnía barvě MAGIC černá metalíza..
#
# ▶ 1.MAJITEL
# ▶ NAJETO POUZE 12<b>3</b>000KM!
# ▶ NEHAVARO ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  539 900 Kč</b></div>
# <div class="inzeratylok">Beroun<br/>266 01</div>
# <div class="inzeratyview">939 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157035970&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157035970&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=3612467&amp;idphone=15827&amp;jmeno=AUTO+fans+Beroun" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157035970.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/157035183/octavia-rs-20tsi-230psm2018facecantoncolumbuslane.php"><img alt="OCTAVIA RS 2.0TSi-230ps/m.2018/FACE/CANTON/COLUMBUS/LANE" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/183/157035183.jpg?t=1661790534" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/157035183/octavia-rs-20tsi-230psm2018facecantoncolumbuslane.php">OCTAVIA RS 2.0TSi-230ps/m.2018/FACE/CANTON/COLUMBUS/LANE</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 21x Platí do 10.10. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">
9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Škoda Octavia <b>3</b> 1.4 TSi 10<b>3</b>kw Ambition
#
# rok výroby 09/201<b>3</b>
# najeto 125 805km
# Pravidelný servis Škoda!
# DPH odečíst nelze
# Auto pochází z dealerství Škoda! Vozidlo má servisní knížku a předávací protokol od CEBIA!
#
# 6 rychlostí, tempomat, dvouzono ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  285 900 Kč</b></div>
# <div class="inzeratylok">Pardubice<br/>530 02</div>
# <div class="inzeratyview">222 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157020354&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157020354&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=25620&amp;idphone=41608&amp;jmeno=Auto+%C5%A0imon" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157020354.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156898684/skoda-octavia-iii-tsi-dsg-fullled-navi-vyhrsedacky-tazne.php"><img alt="Škoda Octavia III TSi DSG FullLED NAVI VYHŘ.SEDAČKY TAŽNÉ" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/684/156898684.jpg?t=1661522848" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156898684/skoda-octavia-iii-tsi-dsg-fullled-navi-vyhrsedacky-tazne.php">Škoda Octavia III TSi DSG FullLED NAVI VYHŘ.SEDAČKY TAŽNÉ</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 7x Platí do 23.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Prodám Škoda Octavia <b>3</b> kombi edice Style
# Motor 1.4 TSi, 110kw / 150k
# Do provozu 04/2017 ( Facelift )
# Najeto 142 249km
# Barva bílá laser weiss
# Palivo benzín
#
# Pravidelný servis, lze ověřit pomocí VIN kódu + protokoly z technických kontrol.
# Posle ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  435 000 Kč</b></div>
# <div class="inzeratylok">Šumperk<br/>787 01</div>
# <div class="inzeratyview">272 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156898684&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156898684&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=532976&amp;idphone=5115&amp;jmeno=Dal%C5%A1%C3%AD+vozy+AutoVELVET+zde" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156898684.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div id="container_two"></div><script charset="utf-8" type="text/javascript">
# var pageOptions = {
#   'pubId': 'pub-3645948300403337',
#   'query' : 'octávia 3',
#   "channel": "4719857758",  'linkTarget' : '_blank',
# 'styleId' : '6171314811',  'hl': 'cs'
# };
#
# var adblock1 = {
#   'container': 'container_one',
#   'width': 'auto',
#   'maxTop' : 2
# };
#
# var adblock2 = {
#   'container': 'container_two',
#   'width': 'auto',
#   'number' : 2
# };
#
# _googCsa('ads', pageOptions, adblock2);</script>
# <br/><div class="strankovani">Stránka: <b><span class="cisla">1</span></b> <a href="/20/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">2</a> <a href="/40/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">3</a> <a href="/60/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">4</a> <a href="/80/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">5</a> <a href="/100/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">6</a> <a href="/120/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">7</a> <a href="/140/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order=">8</a> <a href="/20/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=&amp;cenaod=&amp;cenado=&amp;order="><b>Další</b></a></div><br/><br/><br/>
# </div></div><br/>
#
# ©2022 Bazoš -  <b>Inzerce, Bazar </b><br/>
# <a href="https://www.bazos.cz/napoveda.php">Nápověda</a>, <a href="https://www.bazos.cz/dotazy.php">Dotazy</a>, <a href="https://www.bazos.cz/hodnoceni.php">Hodnocení</a>, <a href="https://www.bazos.cz/kontakt.php">Kontakt</a>, <a href="https://www.bazos.cz/reklama.php">Reklama</a>, <a href="https://www.bazos.cz/podminky.php">Podmínky</a>, <a href="https://www.bazos.cz/ochrana-udaju.php">Ochrana údajů</a>, <a href="https://www.bazos.cz/rss.php?rub=au&amp;hledat=oct%c3%a1via+3">RSS</a>, <a href="/inzeraty/oct%C3%A1via-3/?vkm=m" rel="nofollow">Mobilní verze</a><br/>
#
# Inzeráty Auto celkem: <b>328041</b>, za 24 hodin: <b>17026</b><br/><br/>
# <a href="https://www.bazos.cz/mapa-kategorie.php">Mapa kategorií</a>, <a href="https://auto.bazos.cz/mapa-search.php">Nejvyhledávanější výrazy</a>
# <br/>
# Země: <a href="https://auto.bazos.cz">Česká republika</a>, <a href="https://auto.bazos.sk">Slovensko</a>, <a href="https://auto.bazos.pl">Polsko</a>, <a href="https://auto.bazos.at">Rakousko</a>
# <br/>
# <br/>
# </div>
# <script>
# const cyrb53 = function(str, seed = 0) {
#    let h1 = 0xdeadbeef ^ seed,
#       h2 = 0x41c6ce57 ^ seed;
#    for (let i = 0, ch; i < str.length; i++) {
#       ch = str.charCodeAt(i);
#       h1 = Math.imul(h1 ^ ch, 2654435761);
#       h2 = Math.imul(h2 ^ ch, 1597334677);
#    }
#    h1 = Math.imul(h1 ^ h1 >>> 16, 2246822507) ^ Math.imul(h2 ^ h2 >>> 13, 3266489909);
#    h2 = Math.imul(h2 ^ h2 >>> 16, 2246822507) ^ Math.imul(h1 ^ h1 >>> 13, 3266489909);
#    return 4294967296 * (2097151 & h2) + (h1 >>> 0);
# };
#
# let clientIP = "193.165.97.18";
# let validityInterval = Math.round (new Date() / 1000 / 3600 / 24 / 4);
# let clientIDSource = clientIP + ";" + window.location.host + ";" + navigator.userAgent + ";" + navigator.language + ";" + validityInterval;
# let clientIDHashed = cyrb53(clientIDSource).toString(16);
#
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-58407-2', {
#    'storage': 'none',
#    'clientId': clientIDHashed
# });
# ga('set', 'anonymizeIp', true);
# ga('send', 'pageview');
# </script>
# <!-- (C)2000-2015 Gemius SA - gemiusAudience / bazos.cz / Auto -->
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var pp_gemius_identifier = 'bJhA5BvMT3wDaES8liHTRJcg33lUtYc4hMco9wVxqGn.v7';
# // lines below shouldn't be edited
# function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
# gemius_pending('gemius_hit'); gemius_pending('gemius_event'); gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
# (function(d,t) {try {var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':''); gt.setAttribute('async','async');
# gt.setAttribute('defer','defer'); gt.src=l+'://spir.hit.gemius.pl/xgemius.js'; s.parentNode.insertBefore(gt,s);} catch (e) {}})(document,'script');
# //--><!]]>
# </script>
# </body>
# </html>, <!DOCTYPE html>
# <html lang="cs">
# <head>
# <title>Octávia 3 bazar - Auto | Bazoš.cz</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Auto - Octávia 3 bazar. Vybírejte z 2 149 inzerátů. Prodej snadno a rychle na Bazoši. Přes půl milionů uživatelů za den. Najděte co potřebujete." name="description"/><link href="https://auto.bazos.cz/20/?hledat=oct%c3%a1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=" rel="canonical"/><meta content="1055875657" property="fb:admins"/>
# <meta content="NOINDEX" name="ROBOTS"/>
# <link href="https://www.bazos.cz/bazos60s.css" rel="stylesheet" type="text/css"/><link as="image" href="https://www.bazos.cz/obrazky/bazos.svg" rel="preload"/>
# <link href="https://www.bazos.cz/bazosprint.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://www.bazos.cz/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.bazos.cz/obrazky/icon-192x192.png" rel="icon" sizes="192x192"/>
# ...
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157058415&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157058415&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=38069&amp;idphone=255421&amp;jmeno=AUTOD%C3%8DLYUH" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157058415.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/157029392/skoda-octavia-iii-18tsi-dsg-4x4.php"><img alt="Škoda Octavia III 1.8TSI DSG 4x4" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/392/157029392.jpg?t=1661803835" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/157029392/skoda-octavia-iii-18tsi-dsg-4x4.php">Škoda Octavia III 1.8TSI DSG 4x4</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 1x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Prodám Škoda Octavia <b>3</b>, s motorem 1.8TSI o výkonu 1<b>3</b>2 KW, ve spojení s 6. stupňovou mokrou automatickou převodovkou DSG (DQ250) s pohonem 4x4. Má najeto 197 000 km. Výbava je velmi bohatá, kromě základní výbavy jako třeba 4 el. okna, abs, esp a další ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  285 000 Kč</b></div>
# <div class="inzeratylok">Vsetín<br/>756 22</div>
# <div class="inzeratyview">219 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157029392&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157029392&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=87763&amp;idphone=362553&amp;jmeno=%2A%2A%2A" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157029392.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156812248/skoda-octavia-challenge-rs-combi-20-tdi-135kw.php"><img alt="Skoda octavia Challenge rs combi 2.0 tdi 135kw" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/248/156812248.jpg?t=1661766999" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156812248/skoda-octavia-challenge-rs-combi-20-tdi-135kw.php">Skoda octavia Challenge rs combi 2.0 tdi 135kw</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 1x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">ŠKODA OCTAVIA <b>3</b> RS COMBI 2.0 TDI 1<b>3</b>5KW
# Motor: 2.0 TDI 1<b>3</b>5 KW
# Najeto: 191500
# Převodovka: Manualni
# Pohon: Přední
# Barva: bila
# Rok vyroby: 09/2015
# Počet míst: 5
# 2x Klíče
# Auto Nehavarovane
#
#
# DOŽIVOTNÍ GARANCE NÁJEZDU KM I PŮVODU VOZIDLA SAMOZ ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  369 900 Kč</b></div>
# <div class="inzeratylok">Cheb<br/>353 01</div>
# <div class="inzeratyview">340 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156812248&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156812248&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=3735534&amp;idphone=103910&amp;jmeno=Marek" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156812248.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156812397/skoda-octavia-3-facelift-20tdi-110kw.php"><img alt="Skoda octavia 3 facelift 2.0tdi 110kw" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/397/156812397.jpg?t=1661766968" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156812397/skoda-octavia-3-facelift-20tdi-110kw.php">Skoda octavia 3 facelift 2.0tdi 110kw</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 1x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Prodám Škoda Octavia <b>3</b> facelift
# 2.0TDi 110kW common rail
# r.v. 10/2017
# najeto 157 450km
# K vozu 2x klíč.
# PÍSEMNÁ ZÁRUKA NA PŮVOD VOZU A STAV NAJETÝCH KM
#
# Pravidelný servis ŠKODA -servisováno v autorizovaném SERVISE ŠKODA -servisní knížka
#
# V ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  359 900 Kč</b></div>
# <div class="inzeratylok">Cheb<br/>353 01</div>
# <div class="inzeratyview">137 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156812397&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156812397&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=3735534&amp;idphone=103910&amp;jmeno=Marek" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156812397.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/157012610/skoda-octavia-320-tdi110-kw112014crtop-stav-nehavar.php"><img alt="Škoda Octavia 3,2.0 TDI,110 kW,11/2014,ČR,TOP stav, nehavar." class="obrazek" height="105" src="https://www.bazos.cz/img/1t/610/157012610.jpg?t=1661760197" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/157012610/skoda-octavia-320-tdi110-kw112014crtop-stav-nehavar.php">Škoda Octavia 3,2.0 TDI,110 kW,11/2014,ČR,TOP stav, nehavar.</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 1x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Škoda Octavia III, 2.0 TDI, 110 kW, Modelový rok 2015, TOP stav, nehavarované, CEBIA certifikát a výpis na vyžádání.
#
# Najeto 19<b>3</b> 150 km - el. servisní kniha, původ ČR = ověřitelné km.
# Barva bílá, manuální 6ti rychlostní převodovka.
#
# Datum výroby ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  288 000 Kč</b></div>
# <div class="inzeratylok">Plzeň<br/>301 00</div>
# <div class="inzeratyview">140 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157012610&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157012610&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=4007376&amp;idphone=594028&amp;jmeno=VW" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157012610.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/157005391/octavia-3-rs-20-tdi.php"><img alt="Octavia 3 Rs 2.0 tdi" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/391/157005391.jpg?t=1661753716" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/157005391/octavia-3-rs-20-tdi.php">Octavia 3 Rs 2.0 tdi</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 1x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Skoda Octavia <b>3</b> 2.0 tdi 1<b>3</b>5kw
# modrá met
# rok 11-201<b>3</b>
# najeto 1<b>3</b>8500km servisní kniha
# navigace Amundsen
# Canton hudba
# dvouzonová digitální klima
# vyhřívané sedačky
# jízdní režimy Mode
# multifunkční volant
# el. sklopna zrcátka
# alu kola Geminy r18” zánov ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  353 000 Kč</b></div>
# <div class="inzeratylok">Kolín<br/>289 11</div>
# <div class="inzeratyview">185 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=157005391&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=157005391&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=72461&amp;idphone=930572&amp;jmeno=Radek" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/157005391.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156145341/octavia.php"><img alt="Octavia" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/341/156145341.jpg?t=1661838701" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156145341/octavia.php">Octavia</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 2x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Skoda Octavia <b>3</b> kombi 2.0 tdi 110kw manuální převodovka 6q, stříbrná metalíza.rok 2014  ,dvouzonová digitální klima, vyhřívané sedačky kožený volant,,alu kola r17”, komplet po servisu oleje filtry  nová baterie a nové přední pneu protokoly všech serv ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  279 000 Kč</b></div>
# <div class="inzeratylok">Kolín<br/>289 11</div>
# <div class="inzeratyview">656 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156145341&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156145341&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=5775787&amp;idphone=3321625&amp;jmeno=Patrik+" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156145341.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156943422/sada-kol-octavia-35-zimni-plech-2055516.php"><img alt="Sada kol octavia 3.5 zimní plech 205/55/16" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/422/156943422.jpg?t=1661750630" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156943422/sada-kol-octavia-35-zimni-plech-2055516.php">Sada kol octavia 3.5 zimní plech 205/55/16</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 1x Platí do 5.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Sada zimních pneu na plechových rafcich na octavia <b>3</b>.5 vzorek 7-8mm 2x dunlop 2xhankook </div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  3 500 Kč</b></div>
# <div class="inzeratylok">Praha - východ<br/>250 67</div>
# <div class="inzeratyview">81 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156943422&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156943422&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=4342694&amp;idphone=321010&amp;jmeno=Ji%C5%99%C3%AD+" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156943422.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div id="container_two"></div><script charset="utf-8" type="text/javascript">
# var pageOptions = {
#   'pubId': 'pub-3645948300403337',
#   'query' : 'octávia 3',
#   "channel": "4719857758",  'linkTarget' : '_blank',
# 'styleId' : '6171314811',  'adPage': 3,
#   'hl': 'cs'
# };
#
# var adblock1 = {
#   'container': 'container_one',
#   'width': 'auto',
#   'maxTop' : 2
# };
#
# var adblock2 = {
#   'container': 'container_two',
#   'width': 'auto',
#   'number' : 2
# };
#
# _googCsa('ads', pageOptions, adblock2);</script>
# <br/><div class="strankovani">Stránka: <a href="/20/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order="><b>Předchozí</b></a> <a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">1</a> <a href="/20/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">2</a> <b><span class="cisla">3</span></b> <a href="/60/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">4</a> <a href="/80/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">5</a> <a href="/100/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">6</a> <a href="/120/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">7</a> <a href="/140/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">8</a> <a href="/160/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">9</a> <a href="/180/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">10</a> <a href="/60/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order="><b>Další</b></a></div><br/><br/><br/>
# </div></div><br/>
#
# ©2022 Bazoš -  <b>Inzerce, Bazar </b><br/>
# <a href="https://www.bazos.cz/napoveda.php">Nápověda</a>, <a href="https://www.bazos.cz/dotazy.php">Dotazy</a>, <a href="https://www.bazos.cz/hodnoceni.php">Hodnocení</a>, <a href="https://www.bazos.cz/kontakt.php">Kontakt</a>, <a href="https://www.bazos.cz/reklama.php">Reklama</a>, <a href="https://www.bazos.cz/podminky.php">Podmínky</a>, <a href="https://www.bazos.cz/ochrana-udaju.php">Ochrana údajů</a>, <a href="https://www.bazos.cz/rss.php?rub=au&amp;humkreis=25&amp;hledat=oct%c3%a1via+3">RSS</a>, <a href="/40/?hledat=oct%c3%a1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=&amp;vkm=m" rel="nofollow">Mobilní verze</a><br/>
#
# Inzeráty Auto celkem: <b>328041</b>, za 24 hodin: <b>17026</b><br/><br/>
# <a href="https://www.bazos.cz/mapa-kategorie.php">Mapa kategorií</a>, <a href="https://auto.bazos.cz/mapa-search.php">Nejvyhledávanější výrazy</a>
# <br/>
# Země: <a href="https://auto.bazos.cz">Česká republika</a>, <a href="https://auto.bazos.sk">Slovensko</a>, <a href="https://auto.bazos.pl">Polsko</a>, <a href="https://auto.bazos.at">Rakousko</a>
# <br/>
# <br/>
# </div>
# <script>
# const cyrb53 = function(str, seed = 0) {
#    let h1 = 0xdeadbeef ^ seed,
#       h2 = 0x41c6ce57 ^ seed;
#    for (let i = 0, ch; i < str.length; i++) {
#       ch = str.charCodeAt(i);
#       h1 = Math.imul(h1 ^ ch, 2654435761);
#       h2 = Math.imul(h2 ^ ch, 1597334677);
#    }
#    h1 = Math.imul(h1 ^ h1 >>> 16, 2246822507) ^ Math.imul(h2 ^ h2 >>> 13, 3266489909);
#    h2 = Math.imul(h2 ^ h2 >>> 16, 2246822507) ^ Math.imul(h1 ^ h1 >>> 13, 3266489909);
#    return 4294967296 * (2097151 & h2) + (h1 >>> 0);
# };
#
# let clientIP = "193.165.97.18";
# let validityInterval = Math.round (new Date() / 1000 / 3600 / 24 / 4);
# let clientIDSource = clientIP + ";" + window.location.host + ";" + navigator.userAgent + ";" + navigator.language + ";" + validityInterval;
# let clientIDHashed = cyrb53(clientIDSource).toString(16);
#
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-58407-2', {
#    'storage': 'none',
#    'clientId': clientIDHashed
# });
# ga('set', 'anonymizeIp', true);
# ga('send', 'pageview');
# </script>
# <!-- (C)2000-2015 Gemius SA - gemiusAudience / bazos.cz / Auto -->
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var pp_gemius_identifier = 'bJhA5BvMT3wDaES8liHTRJcg33lUtYc4hMco9wVxqGn.v7';
# // lines below shouldn't be edited
# function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
# gemius_pending('gemius_hit'); gemius_pending('gemius_event'); gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
# (function(d,t) {try {var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':''); gt.setAttribute('async','async');
# gt.setAttribute('defer','defer'); gt.src=l+'://spir.hit.gemius.pl/xgemius.js'; s.parentNode.insertBefore(gt,s);} catch (e) {}})(document,'script');
# //--><!]]>
# </script>
# </body>
# </html>]

# %% [markdown]
# There are 20 adds plus other page elements. Lets pick just one add to see their construction.

# %% [markdown]
# There are several elements, which are important to us. In this section, we are interested in add id, which we are able to extract from href in element a on the second line. Its the number after "inzerat/". We are also interested in the href itself, since it is our link to follow to the actual add. Another element important to us is h2 class = "nadpis", which contains title of the add, from which we can extract type of car. And the last interesting element is span with class "velikost10", which reffers to date uploaded.
#
# Now we can follow the link to the actual add page to see its content.

# %%
print(soup_list[1])
# Out:
# <!DOCTYPE html>
# <html lang="cs">
# <head>
# <title>Octávia 3 bazar - Auto | Bazoš.cz</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Auto - Octávia 3 bazar. Vybírejte z 2 150 inzerátů. Prodej snadno a rychle na Bazoši. Přes půl milionů uživatelů za den. Najděte co potřebujete." name="description"/><link href="https://auto.bazos.cz/20/?hledat=oct%c3%a1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=" rel="canonical"/><meta content="1055875657" property="fb:admins"/>
# <meta content="NOINDEX" name="ROBOTS"/>
# <link href="https://www.bazos.cz/bazos60s.css" rel="stylesheet" type="text/css"/><link as="image" href="https://www.bazos.cz/obrazky/bazos.svg" rel="preload"/>
# <link href="https://www.bazos.cz/bazosprint.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://www.bazos.cz/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.bazos.cz/obrazky/icon-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://www.bazos.cz/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://www.bazos.cz/rss.php?rub=au&amp;humkreis=25&amp;hledat=oct%c3%a1via+3" rel="alternate" title="Auto - Octávia 3 RSS | Bazos.cz" type="application/rss+xml"/>
# <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
# (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
#   arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
# </script><script>
# var xhr = new XMLHttpRequest();
# var naseptavac_value = '';
# function naseptavac(value) {
#   if (value=='')  {
#   	naseptavac_value = '';
#   	document.getElementById('vysledek').innerHTML='';
#   	}
# else {
# 	if (naseptavac_value == value) {
# 		return false;
# 	}
# 	naseptavac_value = value;
# 	setTimeout(function () {
# 		if (naseptavac_value != value) {
# 			return false;
# 		}
# 		xhr.onreadystatechange = function() {
#  		 if (this.readyState == 4 && naseptavac_value == value){
# 				document.getElementById('vysledek').innerHTML = this.responseText;
# 			}
#  		 };
# 		xhr.open('GET', '/suggest.php?rubnas=AU&catnas=&qnas='+encodeURIComponent(naseptavac_value));
# 		xhr.send();
# 	}, 250);
# }
# }
#
# var naseptavacpsc_value = '';
# function naseptavacpsc(value) {
#   if (value=='')  {
#   	naseptavacpsc_value = '';
#   	document.getElementById('vysledekpsc').innerHTML='<table cellpadding=\"3\" cellspacing=\"0\" class=\"tablenaspsc\"><tr><td class=\"act\" onclick=\"getLocation();\"><b>Inzeráty v okolí</b></td></tr></table>';
#   	}
# else {
# 	if (naseptavacpsc_value == value) {
# 		return false;
# 	}
# 	naseptavacpsc_value = value;
# 	setTimeout(function () {
# 		if (naseptavacpsc_value != value) {
# 			return false;
# 		}
# 		xhr.onreadystatechange = function() {
#  		 if (this.readyState == 4 && naseptavacpsc_value == value){
# 				document.getElementById('vysledekpsc').innerHTML = this.responseText;
# 			}
#  		 };
# 		xhr.open('GET', '/suggestpsc.php?qnaspsc='+encodeURIComponent(naseptavacpsc_value));
# 		xhr.send();
# 	}, 250);
# }
# }
#
# function getLocation() {
# if (navigator.geolocation) {navigator.geolocation.getCurrentPosition(showPosition);}
# else {document.getElementById('hlokalita').value = '';}
# }
# function showPosition(position) {
# 		xhr.onreadystatechange = function() {
#  		 if (this.readyState == 4){
# 				document.getElementById('hlokalita').value = this.responseText;
# 				document.forms['formt'].submit();
# 			}
#  		 };
# 		xhr.open('GET', '/zip.php?latitude='+encodeURIComponent(position.coords.latitude)+'&longitude='+encodeURIComponent(position.coords.longitude));
# 		xhr.send();
# }
#
# var agent_value = '';
# function agentclick() {
#   if (document.getElementById('agentmail').value=='')  {
#   	document.getElementById("agentmail").focus();
#     return false;
#   	}
# else {
# agent_value = document.getElementById('agentmail').value;
# xhr.onreadystatechange = function() {
#   if (this.readyState == 4){
# 				document.getElementById('overlay').innerHTML = this.responseText;
# 			}
#   };
# xhr.open("GET", '/agent.php?hledat=octávia 3&rubrikav=AU&hlokalita=&humkreis=25&cenaod=&cenado=&cat=&typ=&agentmail='+encodeURIComponent(agent_value));
# xhr.send();
# }
# }
#
# function odeslatrequest(value) {
# xhr.onreadystatechange = function() {
#   if (this.readyState == 4){
# 				document.getElementById('overlay').innerHTML = this.responseText;
# 			}
#   };
# xhr.open("GET", value);
# xhr.send();
# }
# function overlay() {
# 	el = document.getElementById("overlay");
# 	el.style.display = (el.style.display == "inline") ? "none" : "inline";
# }
# </script>
# <script async="" src="https://www.bazos.cz/eucookiecz.js"></script></head>
# <body>
# <div class="sirka">
# <div class="listalogor">
# <div class="listalogol"><a href="https://www.bazos.cz/" title="Bazos.cz - Inzerce, bazar"><img alt="Bazos.cz - Inzerce, inzeráty" height="34" src="https://www.bazos.cz/obrazky/bazos.svg" width="199"/></a></div>
# <div class="listalogom"><b>... bazar pro každého</b></div>
# <div class="listalogop"><a href="https://www.bazos.cz/oblibene.php"><b>Oblíbené inzeráty</b></a> <a href="https://www.bazos.cz/moje-inzeraty.php"><b>Moje inzeráty</b></a> <a href="/pridat-inzerat.php"><b><span class="pridati">Přidat inzerát</span></b></a></div>
# </div>
# <form id="formt" method="get" name="formt">
# <div class="listah">
# <div class="rubriky">
# <b>
# Co: <span class="vysokoli"><span id="vysledek"></span><input autocomplete="off" id="hledat" maxlength="256" name="hledat" onkeyup="naseptavac(this.value);" size="17" title="Co? Vyhledávaný výraz" type="search" value="octávia 3"/></span>
# <select name="rubriky" onchange="this.form.submit();" title="Vyber rubriku">
# <option value="www">Všechny rubriky</option>
# <option selected="" value="auto">Auto</option><option value="deti">Děti</option><option value="dum">Dům a zahrada</option><option value="elektro">Elektro</option><option value="foto">Foto</option><option value="hudba">Hudba</option><option value="knihy">Knihy</option><option value="mobil">Mobily</option><option value="motorky">Motorky</option><option value="nabytek">Nábytek</option><option value="obleceni">Oblečení</option><option value="pc">PC</option><option value="prace">Práce</option><option value="reality">Reality</option><option value="sluzby">Služby</option><option value="sport">Sport</option><option value="stroje">Stroje</option><option value="vstupenky">Vstupenky</option><option value="zvirata">Zvířata</option><option value="ostatni">Ostatní</option></select>
#
# Lokalita: <span class="vysokolipsc"><span id="vysledekpsc"></span><input autocomplete="off" id="hlokalita" maxlength="25" name="hlokalita" onclick="naseptavacpsc(this.value);" onkeyup="naseptavacpsc(this.value);" size="4" style="-webkit-appearance: none;" title="Kde? PSČ (místo)" type="search" value=""/></span>
# Okolí: <input name="humkreis" size="3" style="width: 25px;" title="Okolí v km" value="25"/> km
# Cena od: <input maxlength="12" name="cenaod" size="5" title="Cena od Kč" value=""/> - do: <input maxlength="12" name="cenado" size="5" title="Cena do Kč" value=""/> Kč <input name="Submit" type="submit" value="Hledat"/>
# <input name="kitx" type="hidden" value="ano"/></b>
# </div>
# </div>
# </form>
# <div class="drobky"><a href="https://www.bazos.cz/" title="Inzerce Bazoš">Hlavní stránka</a>  &gt; <a href="https://auto.bazos.cz">Auto</a> &gt; <h1 class="nadpiskategorie">octávia 3</h1></div>
# <br/>
# <div class="flexmain"><div class="menuleft">
# <div class="nadpismenu">Osobní auta</div>
# <div class="barvalmenu">
# <div class="barvaleva">
# <a href="/alfa/">Alfa Romeo</a>
# <a href="/audi/">Audi</a>
# <a href="/bmw/">BMW</a>
# <a href="/citroen/">Citroën</a>
# <a href="/dacia/">Dacia</a>
# <a href="/fiat/">Fiat</a>
# <a href="/ford/">Ford</a>
# <a href="/honda/">Honda</a>
# <a href="/hyundai/">Hyundai</a>
# <a href="/chevrolet/">Chevrolet</a>
# <a href="/kia/">Kia</a>
# <a href="/mazda/">Mazda</a>
# <a href="/mercedes/">Mercedes-Benz</a>
# <a href="/mitsubishi/">Mitsubishi</a>
# <a href="/nissan/">Nissan</a>
# <a href="/opel/">Opel</a>
# <a href="/peugeot/">Peugeot</a>
# <a href="/renault/">Renault</a>
# <a href="/seat/">Seat</a>
# <a href="/suzuki/">Suzuki</a>
# <a href="/skoda/">Škoda</a>
# <a href="/toyota/">Toyota</a>
# <a href="/volkswagen/">Volkswagen</a>
# <a href="/volvo/">Volvo</a>
# <a href="/ostatni/">Ostatní značky</a>
# <br/>
# <a href="https://elektro.bazos.cz/autoradia/">Autorádia</a>
# <a href="https://pc.bazos.cz/gps/">GPS navigace</a>
# <a href="/havarovana/">Havarovaná auta</a>
# <a href="/nahradnidily/">Náhradní díly</a>
# <a href="/pneumatiky/">Pneumatiky, kola</a>
# <a href="/prislusenstvi/">Příslušenství</a>
# <a href="/tuning/">Tuning</a>
# <a href="/veterani/">Veteráni</a>
# </div></div>
# <br/>
# <div class="nadpismenu">Užitková vozidla</div>
# <div class="barvalmenu">
# <div class="barvaleva">
# <a href="/autobusy/">Autobusy</a>
# <a href="/dodavka/">Dodávky</a>
# <a href="/mikrobus/">Mikrobusy</a>
# <a href="/karavany/">Karavany, vozíky</a>
# <a href="/nakladni/">Nákladní auta</a>
# <a href="/pickup/">Pick-up</a>
# <a href="https://stroje.bazos.cz/">Stroje</a>
# <a href="/ostatniuzitkova/">Ostatní</a>
# <br/>
# <a href="/havarovanauzitkova/">Havarovaná</a>
# <a href="/nahradnidilyuzitkova/">Náhradní díly</a>
# </div>
# </div>
# <br/>
# <div class="nadpismenu">Moto</div>
# <div class="barvalmenu">
# <div class="barvaleva">
# <a href="https://motorky.bazos.cz/">Motorky, Skútry</a>
# </div></div>
# <br/><span class="mobilskryt">
# <iframe src="https://www.bazos.cz/reklamajasminka.php" style="border: 0px;width:100%; height:300px;overflow: hidden;"></iframe></span></div><div class="maincontent">
# <div class="listainzerat inzeratyflex">
# <div class="inzeratynadpis"><img alt="List inzerátů" class="gallerylista" height="16" src="https://www.bazos.cz/obrazky/list.gif" width="18"/> <a href="/20/?hledat=oct%c3%a1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=&amp;gal=g" rel="nofollow"><img alt="Galerie" class="gallerylist" height="16" src="https://www.bazos.cz/obrazky/gallery.gif" width="18"/></a> Zobrazeno 21-40 inzerátů z 2 150</div>
# <div class="inzeratycena"><b><a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=1" rel="nofollow">Cena</a></b></div>
# <div class="inzeratylok">Lokalita</div>
# <div class="inzeratyview"><a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=3" rel="nofollow">Zobrazeno</a></div>
# </div><button onclick="odeslatrequest('/agent.php?teloverit=');overlay();" type="button">Nové inzeráty e-mailem</button>
# <div id="overlay">
# <div></div>
# </div>
# <div id="container_one"></div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156928243/skoda-octavia-3-18-tsi-132kw-85tkm-1majitel-acc-navi-led.php"><img alt="Škoda Octavia 3 1.8 TSi 132kw-85tkm-1.Majitel-ACC-Navi-Led" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/243/156928243.jpg?t=1661594881" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156928243/skoda-octavia-3-18-tsi-132kw-85tkm-1majitel-acc-navi-led.php">Škoda Octavia 3 1.8 TSi 132kw-85tkm-1.Majitel-ACC-Navi-Led</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 6x Platí do 23.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Škoda Octavia <b>3</b> 1.8 TSi 1<b>3</b>2kw Drive
#
# 1.Majitel
# rok výroby 05/2017
# najeto 85 040km
# Pravidelný servis Škoda!
# Možný odpočet DPH, cena bez DPH <b>3</b>42 89<b>3</b>Kč
# Auto pochází z dealerství Škoda! Vozidlo má servisní knížku a předávací protokol od CEBIA!
#
#  ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  414 900 Kč</b></div>
# <div class="inzeratylok">Pardubice<br/>530 02</div>
# <div class="inzeratyview">173 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156928243&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156928243&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=25620&amp;idphone=41608&amp;jmeno=Auto+%C5%A0imon" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156928243.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156252288/skoda-octavia-3-fc-16tdi-85kw-koupcr1majitel201977tkm.php"><img alt="ŠKODA OCTAVIA 3 FC 1,6TDi 85kW Koup.ČR,1.majitel,2019,77tkm" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/288/156252288.jpg?t=1660736870" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156252288/skoda-octavia-3-fc-16tdi-85kw-koupcr1majitel201977tkm.php">ŠKODA OCTAVIA 3 FC 1,6TDi 85kW Koup.ČR,1.majitel,2019,77tkm</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 21x Platí do 22.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">xxxPOZOR NEJEDNÁ SE O DOVOZ ZE ZAHRANIČÍ!xxx- nehrozí riziko stočeného tachometru a právních vad jako u dovozu!
#
# Prodám i na splátky-Škoda Octavia III FC 1,6TDi 85kW Koup.ČR,1.maj.,DPH,Servisní kniha
#
# Pro podnikatele a firmy odpočet DPH!!!
#
#  ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  419 900 Kč</b></div>
# <div class="inzeratylok">Olomouc<br/>772 00</div>
# <div class="inzeratyview">1407 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156252288&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156252288&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=5908&amp;idphone=9427&amp;jmeno=Tom%C3%A1%C5%A1+Kadula-moje+nab%C3%ADdka+aut" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/
a></h2><span class="velikost10"> - <span class="ztop" title="TOP 21x Platí do 20.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">ŠKODA OCTAVIA <b>3</b> FACELIFT 4X4 COMBI 2.0 TDI 1<b>3</b>5KW DSG, 2018, STYLE, PERLEŤ, LED, TAŽNÉ, NAVIGACE, KESSY, NOVE STK, 1.MAJITEL, ODPOČET DPH
# Motor: 2.0 TDI 1<b>3</b>5 KW COMMON-RAIL.
# Převodovka: Automatická převodovka DSG
# Pohon: 4X4
# Barva: Bílá perleťová me ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  352 000 Kč</b></div>
# <div class="inzeratylok">Zlín<br/>760 01</div>
# <div class="inzeratyview">3826 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156116224&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156116224&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=3681079&amp;idphone=24848&amp;jmeno=Kupn%C3%A1mAUTO" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156116224.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156722365/skoda-octavia-iii-rs-4x4-fullled-acc-dcc-columbus-webasto.php"><img alt="Škoda Octavia III RS 4x4 FullLED ACC DCC COLUMBUS WEBASTO" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/365/156722365.jpg?t=1661183049" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156722365/skoda-octavia-iii-rs-4x4-fullled-acc-dcc-columbus-webasto.php">Škoda Octavia III RS 4x4 FullLED ACC DCC COLUMBUS WEBASTO</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 8x Platí do 20.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Prodám Škoda Octavia <b>3</b> RS kombi edice Challenge
# Motor 2.0 TDi Common-Rail 1<b>3</b>5kw / 184k
# Do provozu 0<b>3</b>/2018 ( Facelift )
# Najeto 157 460km
# Barva šedá steel grau
# Palivo nafta
#
# Pravidelný servis, lze ověřit pomocí VIN kódu + protokoly z technických ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  579 000 Kč</b></div>
# <div class="inzeratylok">Šumperk<br/>787 01</div>
# <div class="inzeratyview">1641 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156722365&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156722365&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=532976&amp;idphone=5115&amp;jmeno=Dal%C5%A1%C3%AD+vozy+AutoVELVET+zde" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156722365.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156724451/skoda-octavia-iii-tsi-dsg-xenon-columbus-webasto.php"><img alt="Škoda Octavia III TSi DSG XENON COLUMBUS WEBASTO" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/451/156724451.jpg?t=1661183368" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156724451/skoda-octavia-iii-tsi-dsg-xenon-columbus-webasto.php">Škoda Octavia III TSi DSG XENON COLUMBUS WEBASTO</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 7x Platí do 19.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Prodám Škoda Octavia <b>3</b> edice Style
# Motor 1.8 TSi 1<b>3</b>2kw / 179k
# Do provozu 05/201<b>3</b>
# Najeto 140 067km
# Barva šedá platin grau metalíza
# Palivo benzín
#
# Pravidelný servis, lze ověřit pomocí VIN kódu + protokoly z technických kontrol.
# Poslední servis  ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  338 000 Kč</b></div>
# <div class="inzeratylok">Šumperk<br/>787 01</div>
# <div class="inzeratyview">567 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156724451&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156724451&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=532976&amp;idphone=5115&amp;jmeno=Dal%C5%A1%C3%AD+vozy+AutoVELVET+zde" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156724451.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156722270/skoda-octavia-tsi-style-fullled-kamera-vyhrsedacky.php"><img alt="Škoda Octavia TSi STYLE FullLED KAMERA VYHŘ.SEDAČKY" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/270/156722270.jpg?t=1661182979" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156722270/skoda-octavia-tsi-style-fullled-kamera-vyhrsedacky.php">Škoda Octavia TSi STYLE FullLED KAMERA VYHŘ.SEDAČKY</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 7x Platí do 19.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Prodám Škoda Octavia <b>3</b> kombi edice Style
# Motor 1.4 TSi, 110kw / 150k
# Do provozu 10/2017 ( Facelift )
# Najeto 12<b>3</b> 750km
# Barva šedá quarz grau metalíza
# Palivo benzín
#
# Možnost odpočtu DPH. Cena bez DPH je <b>3</b>76.0<b>3</b><b>3</b>,-Kč.
#
# Pravidelný servis Škoda, l ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  455 000 Kč</b></div>
# <div class="inzeratylok">Šumperk<br/>787 01</div>
# <div class="inzeratyview">332 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156722270&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156722270&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail
width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156787528/octavia-3-fl-style-16-tdi-85-kw.php">Octavia 3 FL Style 1.6 TDI 85 Kw r.v. 2019</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 4x Platí do 15.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">Ježděno převážně dálnice (140 km/den), olej měněn vždy po 10 tis. km, aktuálně po servisu, výměna filtrů, oleje, zadních brzdových destiček. Naprosto bez investic.
#
# Výbava vozu
# Bezpečnostní systémy:
# ABS, Elektronická uzávěrka diferenciálu (EDS), ESP, ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  388 000 Kč</b></div>
# <div class="inzeratylok">Olomouc<br/>779 00</div>
# <div class="inzeratyview">133 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156787528&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156787528&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=4400736&amp;idphone=1619271&amp;jmeno=Tomas" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156787528.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156218183/skoda-octavia-3-rs-20tdi-135kw-top-cz-puvod.php"><img alt="Škoda Octavia 3 RS 2.0TDi 135kw - TOP, CZ původ" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/183/156218183.jpg?t=1660934847" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156218183/skoda-octavia-3-rs-20tdi-135kw-top-cz-puvod.php">Škoda Octavia 3 RS 2.0TDi 135kw - TOP, CZ původ</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 14x Platí do 14.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">‼️Prodám‼️
#
# ŠKODA OCTAVIA <b>3</b> RS kombi 2.0TDi 1<b>3</b>5kw
#
# Najeto: 256 147km ✅ CZ původ
# Rok výroby: 09/2014
# Výkon: 1<b>3</b>5kw
# VIN: TMBJK7NE1F006429<b>3</b>
#
# NOVÝ OLEJ a FILTRY✅
# Sada orig. ALU kol✅
# NOVÁ STK✅
#
# výbava: DSG Automatická převodovka, navigace  -  ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  329 999 Kč</b></div>
# <div class="inzeratylok">Most<br/>434 01</div>
# <div class="inzeratyview">3912 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156218183&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156218183&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=25999&amp;idphone=2845415&amp;jmeno=Pavel" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156218183.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div class="inzeraty inzeratyflex">
# <div class="inzeratynadpis"><a href="/inzerat/156487898/skoda-octavia-iii-20-tdi-135kw-4x4-dsg-dph.php"><img alt="ŠKODA OCTAVIA III 2.0 TDI 135KW 4X4 DSG DPH" class="obrazek" height="105" src="https://www.bazos.cz/img/1t/898/156487898.jpg?t=1660994864" width="140"/></a>
# <h2 class="nadpis"><a href="/inzerat/156487898/skoda-octavia-iii-20-tdi-135kw-4x4-dsg-dph.php">ŠKODA OCTAVIA III 2.0 TDI 135KW 4X4 DSG DPH</a></h2><span class="velikost10"> - <span class="ztop" title="TOP 7x Platí do 14.9. 2022">TOP</span> - [30.8. 2022]</span><br/>
# <div class="popis">ŠKODA OCTAVIA <b>3</b> 2.0 TDI 1<b>3</b>5KW 4X4 DSG Style
#
# Rok výroby 10/2017
#
# Najeto 147066 km
#
# Po 1.majiteli
#
# Pojízdné
#
# Druh pohonu: pohon všech kol
#
# airbagy OK
# Motor a převodovka OK
#
# Havarovaná na předek z boku
# prasklá zadní lampa a nárazník
#  ...</div><br/><br/>
# </div>
# <div class="inzeratycena"><b>  259 000 Kč</b></div>
# <div class="inzeratylok">Žďár nad Sázavou<br/>593 01</div>
# <div class="inzeratyview">1835 x</div>
# <div class="inzeratyakce">
# <a class="akce" href="https://www.bazos.cz/report.php?idad=156487898&amp;report=1" rel="nofollow">Označit špatný inzerát</a> <a class="akce" href="https://www.bazos.cz/report.php?idad=156487898&amp;report=2" rel="nofollow">Chybnou kategorii</a> <a class="akce" href="https://www.bazos.cz/hodnoceni.php?idmail=33594&amp;idphone=535624&amp;jmeno=pouzitedily.cz" rel="nofollow">Ohodnotit uživatele</a> <a class="akce" href="/smazat/156487898.php" rel="nofollow">Smazat/Upravit/Topovat</a>
# </div>
# </div>
# <div id="container_two"></div><script charset="utf-8" type="text/javascript">
# var pageOptions = {
#   'pubId': 'pub-3645948300403337',
#   'query' : 'octávia 3',
#   "channel": "4719857758",  'linkTarget' : '_blank',
# 'styleId' : '6171314811',  'adPage': 2,
#   'hl': 'cs'
# };
#
# var adblock1 = {
#   'container': 'container_one',
#   'width': 'auto',
#   'maxTop' : 2
# };
#
# var adblock2 = {
#   'container': 'container_two',
#   'width': 'auto',
#   'number' : 2
# };
#
# _googCsa('ads', pageOptions, adblock2);</script>
# <br/><div class="strankovani">Stránka: <a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order="><b>Předchozí</b></a> <a href="/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">1</a> <b><span class="cisla">2</span></b> <a href="/40/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">3</a> <a href="/60/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">4</a> <a href="/80/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">5</a> <a href="/100/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">6</a> <a href="/120/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">7</a> <a href="/140/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">8</a> <a href="/160/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=">9</a> <a href="/40/?hledat=oct%C3%A1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order="><b>Další</b></a></div><br/><br/><br/>
# </div></div><br/>
#
# ©2022 Bazoš -  <b>Inzerce, Bazar </b><br/>
# <a href="https://www.bazos.cz/napoveda.php">Nápověda</a>, <a href="https://www.bazos.cz/dotazy.php">Dotazy</a>, <a href="https://www.bazos.cz/hodnoceni.php">Hodnocení</a>, <a href="https://www.bazos.cz/kontakt.php">Kontakt</a>, <a href="https://www.bazos.cz/reklama.php">Reklama</a>, <a href="https://www.bazos.cz/podminky.php">Podmínky</a>, <a href="https://www.bazos.cz/ochrana-udaju.php">Ochrana údajů</a>, <a href="https://www.bazos.cz/rss.php?rub=au&amp;humkreis=25&amp;hledat=oct%c3%a1via+3">RSS</a>, <a href="/20/?hledat=oct%c3%a1via+3&amp;hlokalita=&amp;humkreis=25&amp;cenaod=&amp;cenado=&amp;order=&amp;vkm=m" rel="nofollow">Mobilní verze</a><br/>
#
# Inzeráty Auto celkem: <b>328041</b>, za 24 hodin: <b>17026</b><br/><br/>
# <a href="https://www.bazos.cz/mapa-kategorie.php">Mapa kategorií</a>, <a href="https://auto.bazos.cz/mapa-search.php">Nejvyhledávanější výrazy</a>
# <br/>
# Země: <a href="https://auto.bazos.cz">Česká republika</a>, <a href="https://auto.bazos.sk">Slovensko</a>, <a href="https://auto.bazos.pl">Polsko</a>, <a href="https://auto.bazos.at">Rakousko</a>
# <br/>
# <br/>
# </div>
# <script>
# const cyrb53 = function(str, seed = 0) {
#    let h1 = 0xdeadbeef ^ seed,
#       h2 = 0x41c6ce57 ^ seed;
#    for (let i = 0, ch; i < str.length; i++) {
#       ch = str.charCodeAt(i);
#       h1 = Math.imul(h1 ^ ch, 2654435761);
#       h2 = Math.imul(h2 ^ ch, 1597334677);
#    }
#    h1 = Math.imul(h1 ^ h1 >>> 16, 2246822507) ^ Math.imul(h2 ^ h2 >>> 13, 3266489909);
#    h2 = Math.imul(h2 ^ h2 >>> 16, 2246822507) ^ Math.imul(h1 ^ h1 >>> 13, 3266489909);
#    return 4294967296 * (2097151 & h2) + (h1 >>> 0);
# };
#
# let clientIP = "94.63.233.165";
# let validityInterval = Math.round (new Date() / 1000 / 3600 / 24 / 4);
# let clientIDSource = clientIP + ";" + window.location.host + ";" + navigator.userAgent + ";" + navigator.language + ";" + validityInterval;
# let clientIDHashed = cyrb53(clientIDSource).toString(16);
#
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-58407-2', {
#    'storage': 'none',
#    'clientId': clientIDHashed
# });
# ga('set', 'anonymizeIp', true);
# ga('send', 'pageview');
# </script>
# <!-- (C)2000-2015 Gemius SA - gemiusAudience / bazos.cz / Auto -->
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var pp_gemius_identifier = 'bJhA5BvMT3wDaES8liHTRJcg33lUtYc4hMco9wVxqGn.v7';
# // lines below shouldn't be edited
# function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
# gemius_pending('gemius_hit'); gemius_pending('gemius_event'); gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
# (function(d,t) {try {var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':''); gt.setAttribute('async','async');
# gt.setAttribute('defer','defer'); gt.src=l+'://spir.hit.gemius.pl/xgemius.js'; s.parentNode.insertBefore(gt,s);} catch (e) {}})(document,'script');
# //--><!]]>
# </script>
# </body>
# </html>

# %%
#for element in soup_list[1]:
#    x = element.find('div', {'class':'inzeraty inzeratyflex'})
#    y = x.find('div', {'class':'inzeratynadpis'})
#    attribute_a = y.find('a')
#    w = attribute_a.get('href')

# %%
today = date.today()
# by the following code, we get the urls of each advertisement /offer/ (listed in the tabs we work with),
# and save it to "list_of_offers_url"
list_of_offers_url = list()

for element in soup_list:
    x = element.find('div', {'class':'inzeraty inzeratyflex'})
    y = x.find('div', {'class':'inzeratynadpis'})
    attribute_a = y.find('a')
    w = attribute_a.get('href')
    
    attribute_span = y.find('span')
    
    #here we just obtain the date from the particular advertisement to make sure we analyze only ads added today
    date_str = str(attribute_span.text)
    date_str = date_str.replace(" ","")
    date_str = date_str.strip("-[]")
    date_str = date_str.strip("TOP-[]")
    date_object = datetime.strptime(date_str,'%d.%m.%Y')
    date_object = date_object.date()
    
    if date_object != today:
        continue
    
    list_of_offers_url.append(f'https://auto.bazos.cz{w}')
#    time.sleep(0.03)

    
print(list_of_offers_url)
# Out:
# ['https://auto.bazos.cz/inzerat/157075143/skoda-octavia-3-20tdi-110kw-dsg-plna-zaruka-2-roky-zdarma.php', 'https://auto.bazos.cz/inzerat/156928243/skoda-octavia-3-18-tsi-132kw-85tkm-1majitel-acc-navi-led.php', 'https://auto.bazos.cz/inzerat/157061853/skoda-octavia-3-20tdi-110kw-dsg.php']

# %%
def modify_text(text):
    return text.replace(" ", "").replace(".", "").replace("xxx", "000")
def get_numbers_from_text(text):
    import re
    text = modify_text(text)
    pattern = '[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?'
    list_of_numbers = re.findall(pattern, text)
    return list_of_numbers
def find_years(numbers):
    numbers = [x for x in numbers if (float(x) > 1980) and (float(x) < 2030)]
    return numbers
def find_km(numbers):
    numbers = [x for x in numbers if (float(x) > 3000) and (float(x) < 500000)]
    return numbers
def get_context(text, list_of_tokens, year_dictionary = ['egistr', 'rv', 'vyrob', 'výrob', 'prov'], km_dictionary = ['km', 'Km', 'KM', 'ilomet', 'ajet', 'ájez', 'achom', 'atoč'], context_span=20):
    import re
    context = []
    year = 'No match'
    km = 'No match'
    for token in find_years(list_of_tokens):
        all_occurences_indices = [m.start() for m in re.finditer(token, text)]
        for index in all_occurences_indices:
            left_index = max(index - context_span, 0)
            right_index = min(index + context_span, len(text))
            substring = text[left_index: right_index].strip()
            for s in year_dictionary:
                year_find = [m.start() for m in re.finditer(s, substring)]
                if len(year_find) > 0:
                    year = token
    for token in find_km(list_of_tokens):
        all_occurences_indices = [m.start() for m in re.finditer(token, text)]
        for index in all_occurences_indices:
            left_index = max(index - context_span, 0)
            right_index = min(index + context_span, len(text))
            substring = text[left_index: right_index].strip()
            for s in km_dictionary:
                km_find = [m.start() for m in re.finditer(s, substring)]
                if len(km_find) > 0:
                    km = token
    return [year, km]
def get_info(links):
    results = []
    for i in links:
        add_page = requests.get(i)
        soup_add = BeautifulSoup(add_page.text, 'html')
        add = modify_text(soup_add.find('div', {'class':'popisdetail'}).get_text())
        price = soup_add.find('table').find_all('b')[-1].get_text()
        all_numbers = get_numbers_from_text(add)
        context_got = get_context(add, all_numbers)
        result = [i, context_got[0], context_got[1], price.replace(" ", "").replace("Kč", "")]
        results.append(result)
        time.sleep(0.2)
    return results
#link = ['https://auto.bazos.cz/inzerat/157012769/vw-golf-7-20tdi-110kw-107tkm-plna-zaruka-2-roky-zdarma.php', 'https://auto.bazos.cz/inzerat/156954743/skoda-octavia-3dsg-20-tdi.php']
#link = list_of_offers_url
result = get_info(list_of_offers_url)

# %%
print(result)
# Out:
# [['https://auto.bazos.cz/inzerat/157075143/skoda-octavia-3-20tdi-110kw-dsg-plna-zaruka-2-roky-zdarma.php', '2022', '141355', '437000'], ['https://auto.bazos.cz/inzerat/156928243/skoda-octavia-3-18-tsi-132kw-85tkm-1majitel-acc-navi-led.php', '2017', '85040', '414900'], ['https://auto.bazos.cz/inzerat/157061853/skoda-octavia-3-20tdi-110kw-dsg.php', '2013', '185000', 'Dohodou']]

# %%
#import numpy as np
#import pandas as pd

df2 = pd.DataFrame(
    result
)
df2.columns = ['link', 'year_of_manuf', 'km_driven', 'price']

# %%
print(df2)
type(df2)
#dir(df2)
# Out:
#                                                 link year_of_manuf km_driven  \
# 0  https://auto.bazos.cz/inzerat/157075143/skoda-...          2022    141355
# 1  https://auto.bazos.cz/inzerat/156928243/skoda-...          2017     85040
# 2  https://auto.bazos.cz/inzerat/157061853/skoda-...          2013    185000
#
#      price
# 0   437000
# 1   414900
# 2  Dohodou
# pandas.core.frame.DataFrame

# %%
df2.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# Here we can see the description, which we will use to extract parameters of the car. This will be one of the most difficult parts of the project to extract the relevant text in unformated text. There is no official format to the text, so we will have to find a way how to extract this information from various formats.
#
# After retrieving these informations, we will use analysis of the data got from this process.
